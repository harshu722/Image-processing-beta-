# %%
from PIL import image

pil_im = Image.open('empire.jpg')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\1700300699.py in <module>
# ----> 1 from PIL import image
#       2
#       3 pil_im = Image.open('empire.jpg')
#
# ImportError: cannot import name 'image' from 'PIL' (C:\Users\saharsh\anaconda3\lib\site-packages\PIL\__init__.py)

# %%
pip install PIL
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
from PIL import Image
pil_im = Image.open('empire.jpg')

# %%
pil_im = Image.open('empire.jpg').convert('L')

# %%
from PIL import Image
import os

for infile in filelist:
  outfile = os.path.splitext(infile)[0] + ".jpg"
  if infile != outfile:
    try:
      Image.open(infile).save(outfile)
    except IOError:
      print ("cannot convert",) infile
# Out:
#   File "C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\3739829916.py", line 10
#     print ("cannot convert",) infile
#                               ^
# SyntaxError: invalid syntax

# %%
import os

def get_imlist(path):
  """  Returns a list of filenames for
    all jpg images in a directory. """

  return [os.path.join(path,f) for f in os.listdir(path) if f.endswith('.jpg')]

# %%
pil_im.thumbnail((128,128))

# %%
box = (100,100,400,400)
region = pil_im.crop(box)

# %%
region = region.transpose(Image.ROTATE_180)
pil_im.paste(region,box)
# Out:
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\1489485724.py:1: DeprecationWarning: ROTATE_180 is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.ROTATE_180 instead.
#   region = region.transpose(Image.ROTATE_180)

# %%
out = pil_im.resize((128,128))

# %%
out = pil_im.rotate(45)

# %%
from PIL import Image
from pylab import *

# read image to array
im = array(Image.open('empire.jpg'))

# plot the image
imshow(im)

# some points
x = [100,100,400,400]
y = [200,500,200,500]

# plot the points with red star-markers
plot(x,y,'r*')

# line plot connecting the first two points
plot(x[:2],y[:2])

# add title and show the plot
title('Plotting: "empire.jpg"')
show()

# %%
axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plot(x,y) # default blue solid line

plot(x,y,'r*') # red star-markers

plot(x,y,'go-') # green line with circle-markers

plot(x,y,'ks:') # black dotted line with square-markers

# %%
from PIL import Image
from pylab import *

# read image to array
im = array(Image.open('empire.jpg').convert('L'))

# create a new figure
figure()
# don't use colors
gray()
# show contours with origin upper left corner
contour(im, origin='image')
axis('equal')
axis('off')
# Out:
# (0.5, 183.5, 0.5, 272.5)

# %%
figure()
hist(im.flatten(),128)
show()

# %%
from PIL import Image
from pylab import *

im = array(Image.open('empire.jpg'))
imshow(im)
print ('Please click 3 points')
x = ginput(3)
print ('you clicked:',x)
show()
# Out:
# Please click 3 points
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\159856965.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   x = ginput(3)
# you clicked: []

# %%
im = array(Image.open('empire.jpg'))
print(im.shape, im.dtype)

im = array(Image.open('empire.jpg').convert('L'),'f')
print(im.shape, im.dtype)
# Out:
# (273, 184, 3) uint8
# (273, 184) float32

# %%
value = im[i,j,k]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\4088627014.py in <module>
# ----> 1 value = im[i,j,k]
#
# NameError: name 'i' is not defined

# %%
from PIL import Image
from numpy import *

im = array(Image.open('empire.jpg').convert('L'))

im2 = 255 - im # invert image

im3 = (100.0/255) * im + 100 # clamp to interval 100...200

im4 = 255.0 * (im/255.0)**2 # squared

# %%
print int(im.min()), int(im.max())
# Out:
#   File "C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\400875416.py", line 1
#     print int(im.min()), int(im.max())
#           ^
# SyntaxError: invalid syntax

# %%
def imresize(im,sz):
  """  Resize an image array using PIL. """
  pil_im = Image.fromarray(uint8(im))

  return array(pil_im.resize(sz))

# %%
def histeq(im,nbr_bins=256):
  """  Histogram equalization of a grayscale image. """

  # get image histogram
  imhist,bins = histogram(im.flatten(),nbr_bins,normed=True)
  cdf = imhist.cumsum() # cumulative distribution function
  cdf = 255 * cdf / cdf[-1] # normalize

  # use linear interpolation of cdf to find new pixel values
  im2 = interp(im.flatten(),bins[:-1],cdf)

  return im2.reshape(im.shape), cdf

# %%
from PIL import Image
from numpy import *

im = array(Image.open('AquaTermi_lowcontrast.jpg').convert('L'))
im2,cdf = imtools.histeq(im)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\3846757685.py in <module>
#       2 from numpy import *
#       3
# ----> 4 im = array(Image.open('AquaTermi_lowcontrast.jpg').convert('L'))
#       5 im2,cdf = imtools.histeq(im)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3090
#    3091     if filename:
# -> 3092         fp = builtins.open(filename, "rb")
#    3093         exclusive_fp = True
#    3094
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AquaTermi_lowcontrast.jpg'

# %%
def compute_average(imlist):
  """  Compute the average of a list of images. """

  # open first image and make into array of type float
  averageim = array(Image.open(imlist[0]), 'f')

  for imname in imlist[1:]:
    try:
      averageim += array(Image.open(imname))
    except:
      print (imname + '...skipped')
  averageim /= len(imlist)

  # return average as uint8
  return array(averageim, 'uint8')

# %%
from PIL import Image
from numpy import *

def pca(X):
  """  Principal Component Analysis
    input: X, matrix with training data stored as flattened arrays in rows
    return: projection matrix (with important dimensions first), variance
    and mean."""

  # get dimensions
  num_data,dim = X.shape

  # center data
  mean_X = X.mean(axis=0)
  X = X - mean_X

  if dim>num_data:
    # PCA - compact trick used
    M = dot(X,X.T) # covariance matrix
    e,EV = linalg.eigh(M) # eigenvalues and eigenvectors
    tmp = dot(X.T,EV).T # this is the compact trick
    V = tmp[::-1] # reverse since last eigenvectors are the ones we want
    S = sqrt(e)[::-1] # reverse since eigenvalues are in increasing order
    for i in range(V.shape[1]):
      V[:,i] /= S
  else:
    # PCA - SVD used
    U,S,V = linalg.svd(X)
    V = V[:num_data] # only makes sense to return the first num_data

  # return the projection matrix, the variance and the mean
  return V,S,mean_X

# %%
from PIL import Image
from numpy import *
from pylab import *
import pca

im = array(Image.open(imlist[0])) # open one image to get size
m,n = im.shape[0:2] # get the size of the images
imnbr = len(imlist) # get the number of images

# create matrix to store all flattened images
immatrix = array([array(Image.open(im)).flatten()
              for im in imlist],'f')

# perform PCA
V,S,immean = pca.pca(immatrix)

# show some images (mean and 7 first modes)
figure()
gray()
subplot(2,4,1)
imshow(immean.reshape(m,n))
for i in range(7):
  subplot(2,4,i+2)
  imshow(V[i].reshape(m,n))

show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\4200418863.py in <module>
#       2 from numpy import *
#       3 from pylab import *
# ----> 4 import pca
#       5
#       6 im = array(Image.open(imlist[0])) # open one image to get size
#
# ModuleNotFoundError: No module named 'pca'

# %%
pip install pca
# Out:
# Collecting pcaNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pca-1.9.2-py3-none-any.whl (33 kB)
# Requirement already satisfied: numpy in c:\users\saharsh\anaconda3\lib\site-packages (from pca) (1.21.5)
# Requirement already satisfied: scikit-learn in c:\users\saharsh\anaconda3\lib\site-packages (from pca) (1.0.2)
# Requirement already satisfied: requests in c:\users\saharsh\anaconda3\lib\site-packages (from pca) (2.28.2)
# Collecting adjustText
#   Downloading adjustText-0.8-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: matplotlib in c:\users\saharsh\anaconda3\lib\site-packages (from pca) (3.5.2)
# Requirement already satisfied: scipy in c:\users\saharsh\anaconda3\lib\site-packages (from pca) (1.9.1)
# Requirement already satisfied: tqdm in c:\users\saharsh\anaconda3\lib\site-packages (from pca) (4.64.1)
# Collecting scatterd>=1.2.5
#   Downloading scatterd-1.2.5-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: pandas in c:\users\saharsh\anaconda3\lib\site-packages (from pca) (1.4.4)
# Requirement already satisfied: statsmodels in c:\users\saharsh\anaconda3\lib\site-packages (from pca) (0.13.2)
# Collecting colourmap>=1.1.10
#   Downloading colourmap-1.1.10-py3-none-any.whl (7.4 kB)
# Requirement already satisfied: seaborn in c:\users\saharsh\anaconda3\lib\site-packages (from scatterd>=1.2.5->pca) (0.11.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saharsh\anaconda3\lib\site-packages (from matplotlib->pca) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\saharsh\anaconda3\lib\site-packages (from matplotlib->pca) (20.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saharsh\anaconda3\lib\site-packages (from matplotlib->pca) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\saharsh\anaconda3\lib\site-packages (from matplotlib->pca) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\saharsh\anaconda3\lib\site-packages (from matplotlib->pca) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\saharsh\anaconda3\lib\site-packages (from matplotlib->pca) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\saharsh\anaconda3\lib\site-packages (from matplotlib->pca) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saharsh\anaconda3\lib\site-packages (from pandas->pca) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\saharsh\anaconda3\lib\site-packages (from requests->pca) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saharsh\anaconda3\lib\site-packages (from requests->pca) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saharsh\anaconda3\lib\site-packages (from requests->pca) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saharsh\anaconda3\lib\site-packages (from requests->pca) (2022.9.14)
# Requirement already satisfied: joblib>=0.11 in c:\users\saharsh\anaconda3\lib\site-packages (from scikit-learn->pca) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\saharsh\anaconda3\lib\site-packages (from scikit-learn->pca) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\saharsh\anaconda3\lib\site-packages (from statsmodels->pca) (0.5.2)
# Collecting packaging>=20.0
#   Using cached packaging-23.0-py3-none-any.whl (42 kB)
# Requirement already satisfied: colorama in c:\users\saharsh\anaconda3\lib\site-packages (from tqdm->pca) (0.4.5)
# Requirement already satisfied: six in c:\users\saharsh\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->pca) (1.16.0)
# Installing collected packages: packaging, colourmap, adjustText, scatterd, pca
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
# Successfully installed adjustText-0.8 colourmap-1.1.10 packaging-23.0 pca-1.9.2 scatterd-1.2.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tfx 1.12.0 requires packaging<21,>=20, but you have packaging 23.0 which is incompatible.
# ml-pipelines-sdk 1.12.0 requires packaging<21,>=20, but you have packaging 23.0 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 23.0 which is incompatible.
# google-cloud-aiplatform 1.17.1 requires packaging<22.0.0dev,>=14.3, but you have packaging 23.0 which is incompatible.

# %%
from PIL import Image
from numpy import *
from pylab import *
import pca

im = array(Image.open(imlist[0])) # open one image to get size
m,n = im.shape[0:2] # get the size of the images
imnbr = len(imlist) # get the number of images

# create matrix to store all flattened images
immatrix = array([array(Image.open(im)).flatten()
              for im in imlist],'f')

# perform PCA
V,S,immean = pca.pca(immatrix)

# show some images (mean and 7 first modes)
figure()
gray()
subplot(2,4,1)
imshow(immean.reshape(m,n))
for i in range(7):
  subplot(2,4,i+2)
  imshow(V[i].reshape(m,n))

show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\1048952621.py in <module>
#       4 import pca
#       5
# ----> 6 im = array(Image.open(imlist[0])) # open one image to get size
#       7 m,n = im.shape[0:2] # get the size of the images
#       8 imnbr = len(imlist) # get the number of images
#
# NameError: name 'imlist' is not defined

# %%
from PIL import Image
from numpy import *
from scipy.ndimage import filters

im = array(Image.open('empire.jpg').convert('L'))
im2 = filters.gaussian_filter(im,5)
# Out:
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\2990304161.py:6: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   im2 = filters.gaussian_filter(im,5)

# %%
im = array(Image.open('empire.jpg'))
im2 = zeros(im.shape)
for i in range(3):
  im2[:,:,i] = filters.gaussian_filter(im[:,:,i],5)
im2 = uint8(im2)
# Out:
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\4234239855.py:4: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   im2[:,:,i] = filters.gaussian_filter(im[:,:,i],5)

# %%
im2 = array(im2,'uint8')

# %%
from PIL import Image
from numpy import *
from scipy.ndimage import filters

im = array(Image.open('empire.jpg').convert('L'))

# Sobel derivative filters
imx = zeros(im.shape)
filters.sobel(im,1,imx)

imy = zeros(im.shape)
filters.sobel(im,0,imy)

magnitude = sqrt(imx**2+imy**2)
# Out:
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\754510327.py:9: DeprecationWarning: Please use `sobel` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   filters.sobel(im,1,imx)
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\754510327.py:12: DeprecationWarning: Please use `sobel` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   filters.sobel(im,0,imy)

# %%
sigma = 5 # standard deviation

imx = zeros(im.shape)
filters.gaussian_filter(im, (sigma,sigma), (0,1), imx)

imy = zeros(im.shape)
filters.gaussian_filter(im, (sigma,sigma), (1,0), imy)
# Out:
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\3278104611.py:4: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   filters.gaussian_filter(im, (sigma,sigma), (0,1), imx)
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\3278104611.py:7: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   filters.gaussian_filter(im, (sigma,sigma), (1,0), imy)
# array([[0.18393194, 0.18462308, 0.18599093, ..., 0.15536962, 0.15390337,
#         0.15314598],
#        [0.54341028, 0.54548741, 0.54959736, ..., 0.45572499, 0.4513785 ,
#         0.4491334 ],
#        [0.87845072, 0.8819219 , 0.88878714, ..., 0.72609627, 0.7190268 ,
#         0.71537548],
#        ...,
#        [0.212179  , 0.21420038, 0.21920606, ..., 1.89836971, 1.93371482,
#         1.95278595],
#        [0.121908  , 0.12296431, 0.12575625, ..., 1.21580809, 1.23940849,
#         1.25213129],
#        [0.03939538, 0.03971117, 0.04058825, ..., 0.41866692, 0.42696359,
#         0.43143424]])

# %%
from scipy.ndimage import measurements,morphology

# load image and threshold to make sure it is binary
im = array(Image.open('empire.jpg').convert('L'))
im = 1*(im<128)

labels, nbr_objects = measurements.label(im)
print ("Number of objects:", nbr_objects)
# Out:
# Number of objects: 82
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\926952837.py:7: DeprecationWarning: Please use `label` from the `scipy.ndimage` namespace, the `scipy.ndimage.measurements` namespace is deprecated.
#   labels, nbr_objects = measurements.label(im)

# %%
# morphology - opening to separate objects better
im_open = morphology.binary_opening(im,ones((9,5)),iterations=2)

labels_open, nbr_objects_open = measurements.label(im_open)
print ("Number of objects:", nbr_objects_open)
# Out:
# Number of objects: 13
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\373816473.py:2: DeprecationWarning: Please use `binary_opening` from the `scipy.ndimage` namespace, the `scipy.ndimage.morphology` namespace is deprecated.
#   im_open = morphology.binary_opening(im,ones((9,5)),iterations=2)
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_48972\373816473.py:4: DeprecationWarning: Please use `label` from the `scipy.ndimage` namespace, the `scipy.ndimage.measurements` namespace is deprecated.
#   labels_open, nbr_objects_open = measurements.label(im_open)

# %%
data = scipy.io.loadmat('test.mat')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\2536820966.py in <module>
# ----> 1 data = scipy.io.loadmat('test.mat')
#
# NameError: name 'scipy' is not defined

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\saharsh\anaconda3\lib\site-packages (1.9.1)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in c:\users\saharsh\anaconda3\lib\site-packages (from scipy) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
data = scipy.io.loadmat('test.mat')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\2536820966.py in <module>
# ----> 1 data = scipy.io.loadmat('test.mat')
#
# NameError: name 'scipy' is not defined

# %%
pip install SciPy
# Out:
# Requirement already satisfied: SciPy in c:\users\saharsh\anaconda3\lib\site-packages (1.9.1)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in c:\users\saharsh\anaconda3\lib\site-packages (from SciPy) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
data = {}
data['x'] = x
scipy.io.savemat('test.mat',data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\3219583886.py in <module>
#       1 data = {}
#       2 data['x'] = x
# ----> 3 scipy.io.savemat('test.mat',data)
#
# NameError: name 'scipy' is not defined

# %%
from numpy import *

def denoise(im,U_init,tolerance=0.1,tau=0.125,tv_weight=100):
  """ An implementation of the Rudin-Osher-Fatemi (ROF) denoising model
    using the numerical procedure presented in eq (11) A. Chambolle (2005).

    Input: noisy input image (grayscale), initial guess for U, weight of
    the TV-regularizing term, steplength, tolerance for stop criterion.

    Output: denoised and detextured image, texture residual. """

  m,n = im.shape # size of noisy image

  # initialize
  U = U_init
  Px = im # x-component to the dual field
  Py = im # y-component of the dual field
  error = 1

  while (error > tolerance):
    Uold = U

    # gradient of primal variable
    GradUx = roll(U,-1,axis=1)-U # x-component of U's gradient
    GradUy = roll(U,-1,axis=0)-U # y-component of U's gradient

    # update the dual varible
    PxNew = Px + (tau/tv_weight)*GradUx
    PyNew = Py + (tau/tv_weight)*GradUy
    NormNew = maximum(1,sqrt(PxNew**2+PyNew**2))

    Px = PxNew/NormNew # update of x-component (dual)
    Py = PyNew/NormNew # update of y-component (dual)

    # update the primal variable
    RxPx = roll(Px,1,axis=1) # right x-translation of x-component
    RyPy = roll(Py,1,axis=0) # right y-translation of y-component

    DivP = (Px-RxPx)+(Py-RyPy) # divergence of the dual field.
    U = im + tv_weight*DivP # update of the primal variable

    # update of error
    error = linalg.norm(U-Uold)/sqrt(n*m);

  return U,im-U # denoised image and texture residual

# %%
from numpy import *

def denoise(im,U_init,tolerance=0.1,tau=0.125,tv_weight=100):
  """ An implementation of the Rudin-Osher-Fatemi (ROF) denoising model
    using the numerical procedure presented in eq (11) A. Chambolle (2005).

    Input: noisy input image (grayscale), initial guess for U, weight of
    the TV-regularizing term, steplength, tolerance for stop criterion.

    Output: denoised and detextured image, texture residual. """

  m,n = im.shape # size of noisy image

  # initialize
  U = U_init
  Px = im # x-component to the dual field
  Py = im # y-component of the dual field
  error = 1

  while (error > tolerance):
    Uold = U

    # gradient of primal variable
    GradUx = roll(U,-1,axis=1)-U # x-component of U's gradient
    GradUy = roll(U,-1,axis=0)-U # y-component of U's gradient

    # update the dual varible
    PxNew = Px + (tau/tv_weight)*GradUx
    PyNew = Py + (tau/tv_weight)*GradUy
    NormNew = maximum(1,sqrt(PxNew**2+PyNew**2))

    Px = PxNew/NormNew # update of x-component (dual)
    Py = PyNew/NormNew # update of y-component (dual)

    # update the primal variable
    RxPx = roll(Px,1,axis=1) # right x-translation of x-component
    RyPy = roll(Py,1,axis=0) # right y-translation of y-component

    DivP = (Px-RxPx)+(Py-RyPy) # divergence of the dual field.
    U = im + tv_weight*DivP # update of the primal variable

    # update of error
    error = linalg.norm(U-Uold)/sqrt(n*m);

  return U,im-U # denoised image and texture residual

# %%
pip install rof
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement rof (from versions: none)
# ERROR: No matching distribution found for rof

# %%
from numpy import *
from numpy import random
from scipy.ndimage import filters
import rof

# create synthetic image with noise
im = zeros((500,500))
im[100:400,100:400] = 128
im[200:300,200:300] = 255
im = im + 30*random.standard_normal((500,500))

U,T = rof.denoise(im,im)
G = filters.gaussian_filter(im,10)

# save the result
from scipy.misc import imsave
imsave('synth_rof.pdf',U)
imsave('synth_gaussian.pdf',G)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\40812450.py in <module>
#       2 from numpy import random
#       3 from scipy.ndimage import filters
# ----> 4 import rof
#       5
#       6 # create synthetic image with noise
#
# ModuleNotFoundError: No module named 'rof'

# %%
from PIL import Image
from pylab import *
import rof

im = array(Image.open('empire.jpg').convert('L'))
U,T = rof.denoise(im,im)

figure()
gray()
imshow(U)
axis('equal')
axis('off')
show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48972\516052814.py in <module>
#       1 from PIL import Image
#       2 from pylab import *
# ----> 3 import rof
#       4
#       5 im = array(Image.open('empire.jpg').convert('L'))
#
# ModuleNotFoundError: No module named 'rof'
